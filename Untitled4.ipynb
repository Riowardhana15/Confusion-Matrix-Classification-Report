# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, confusion_matrix, classification_report

# %%
df = pd.read_csv('/content/car_purchasing.csv', encoding='ISO-8859-1')
df.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %%
df.drop(columns=['customer name', 'customer e-mail', 'country', 'gender'], inplace=True)

# %%
df.head()
# Out:
#          age  annual Salary  credit card debt    net worth  \
# 0  41.851720    62812.09301      11609.380910  238961.2505
# 1  40.870623    66646.89292       9572.957136  530973.9078
# 2  43.152897    53798.55112      11160.355060  638467.1773
# 3  58.271369    79370.03798      14426.164850  548599.0524
# 4  57.313749    59729.15130       5358.712177  560304.0671
#
#    car purchase amount
# 0          35321.45877
# 1          45115.52566
# 2          42925.70921
# 3          67422.36313
# 4          55915.46248

# %%
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  500 non-null    float64
#  1   annual Salary        500 non-null    float64
#  2   credit card debt     500 non-null    float64
#  3   net worth            500 non-null    float64
#  4   car purchase amount  500 non-null    float64
# dtypes: float64(5)
# memory usage: 19.7 KB
# age                    0
# annual Salary          0
# credit card debt       0
# net worth              0
# car purchase amount    0
# dtype: int64

# %%
plt.scatter(df['annual Salary'] , df['credit card debt'])
plt.xlabel('annual Salary')
plt.ylabel('credit card debt')
plt.title('the corr between credit card debt and annual Salary')
# Out:
# Text(0.5, 1.0, 'the corr between credit card debt and annual Salary')

# %%
sns.pairplot(df)

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
scale = MinMaxScaler()
X = scale.fit_transform(X)
y = scale.fit_transform(y.values.reshape(-1, 1))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# %%
#Trying linear regression
lreg = LinearRegression()
lreg.fit(X_train, y_train)
print('Train score', lreg.score(X_train, y_train))
print('Test score', lreg.score(X_test, y_test))
# Out:
# Train score 0.9999999810793164
# Test score 0.9999999816271219

# %%
y_pred = lreg.predict(X_test)

# %%
ann = Sequential([Dense(32, activation="relu"),
                 Dense(1, activation='linear')])

ann.compile(optimizer='adam',
            loss='mean_squared_error',
            metrics=['mean_absolute_error'])


history = ann.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 31ms/step - loss: 0.4050 - mean_absolute_error: 0.6068 - val_loss: 0.3134 - val_mean_absolute_error: 0.5322
# Epoch 2/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2373 - mean_absolute_error: 0.4538 - val_loss: 0.1671 - val_mean_absolute_error: 0.3762
# Epoch 3/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1206 - mean_absolute_error: 0.3054 - val_loss: 0.0723 - val_mean_absolute_error: 0.2307
# Epoch 4/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0511 - mean_absolute_error: 0.1867 - val_loss: 0.0279 - val_mean_absolute_error: 0.1271
# Epoch 5/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0254 - mean_absolute_error: 0.1260 - val_loss: 0.0170 - val_mean_absolute_error: 0.1054
# Epoch 6/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0205 - mean_absolute_error: 0.1152 - val_loss: 0.0171 - val_mean_absolute_error: 0.1068
# Epoch 7/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0203 - mean_absolute_error: 0.1154 - val_loss: 0.0163 - val_mean_absolute_error: 0.1042
# Epoch 8/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0187 - mean_absolute_error: 0.1100 - val_loss: 0.0149 - val_mean_absolute_error: 0.1000
# Epoch 9/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0173 - mean_absolute_error: 0.1052 - val_loss: 0.0140 - val_mean_absolute_error: 0.0964
# Epoch 10/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0162 - mean_absolute_error: 0.1013 - val_loss: 0.0132 - val_mean_absolute_error: 0.0935
# Epoch 11/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0151 - mean_absolute_error: 0.0976 - val_loss: 0.0125 - val_mean_absolute_error: 0.0909
# Epoch 12/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0141 - mean_absolute_error: 0.0944 - val_loss: 0.0117 - val_mean_absolute_error: 0.0878
# Epoch 13/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0130 - mean_absolute_error: 0.0911 - val_loss: 0.0108 - val_mean_absolute_error: 0.0845
# Epoch 14/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0118 - mean_absolute_error: 0.0870 - val_loss: 0.0098 - val_mean_absolute_error: 0.0803
# Epoch 15/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0108 - mean_absolute_error: 0.0828 - val_loss: 0.0091 - val_mean_absolute_error: 0.0773
# Epoch 16/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0099 - mean_absolute_error: 0.0791 - val_loss: 0.0084 - val_mean_absolute_error: 0.0751
# Epoch 17/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0091 - mean_absolute_error: 0.0764 - val_loss: 0.0079 - val_mean_absolute_error: 0.0733
# Epoch 18/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0085 - mean_absolute_error: 0.0738 - val_loss: 0.0074 - val_mean_absolute_error: 0.0711
# Epoch 19/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0079 - mean_absolute_error: 0.0710 - val_loss: 0.0070 - val_mean_absolute_error: 0.0693
# Epoch 20/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0074 - mean_absolute_error: 0.0688 - val_loss: 0.0066 - val_mean_absolute_error: 0.0674
# Epoch 21/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0069 - mean_absolute_error: 0.0668 - val_loss: 0.0063 - val_mean_absolute_error: 0.0653
# Epoch 22/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0065 - mean_absolute_error: 0.0648 - val_loss: 0.0059 - val_mean_absolute_error: 0.0634
# Epoch 23/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0061 - mean_absolute_error: 0.0628 - val_loss: 0.0057 - val_mean_absolute_error: 0.0615
# Epoch 24/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0057 - mean_absolute_error: 0.0609 - val_loss: 0.0053 - val_mean_absolute_error: 0.0599
# Epoch 25/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0054 - mean_absolute_error: 0.0591 - val_loss: 0.0050 - val_mean_absolute_error: 0.0578
# Epoch 26/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0050 - mean_absolute_error: 0.0573 - val_loss: 0.0047 - val_mean_absolute_error: 0.0559
# Epoch 27/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0047 - mean_absolute_error: 0.0556 - val_loss: 0.0044 - val_mean_absolute_error: 0.0542
# Epoch 28/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0044 - mean_absolute_error: 0.0536 - val_loss: 0.0041 - val_mean_absolute_error: 0.0525
# Epoch 29/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0040 - mean_absolute_error: 0.0515 - val_loss: 0.0039 - val_mean_absolute_error: 0.0508
# Epoch 30/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0037 - mean_absolute_error: 0.0495 - val_loss: 0.0036 - val_mean_absolute_error: 0.0490
# Epoch 31/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0035 - mean_absolute_error: 0.0475 - val_loss: 0.0033 - val_mean_absolute_error: 0.0472
# Epoch 32/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0032 - mean_absolute_error: 0.0455 - val_loss: 0.0031 - val_mean_absolute_error: 0.0454
# Epoch 33/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0029 - mean_absolute_error: 0.0435 - val_loss: 0.0028 - val_mean_absolute_error: 0.0435
# Epoch 34/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0027 - mean_absolute_error: 0.0414 - val_loss: 0.0026 - val_mean_absolute_error: 0.0417
# Epoch 35/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0024 - mean_absolute_error: 0.0395 - val_loss: 0.0024 - val_mean_absolute_error: 0.0400
# Epoch 36/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0022 - mean_absolute_error: 0.0375 - val_loss: 0.0021 - val_mean_absolute_error: 0.0380
# Epoch 37/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0020 - mean_absolute_error: 0.0356 - val_loss: 0.0020 - val_mean_absolute_error: 0.0365
# Epoch 38/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0018 - mean_absolute_error: 0.0337 - val_loss: 0.0018 - val_mean_absolute_error: 0.0346
# Epoch 39/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0016 - mean_absolute_error: 0.0320 - val_loss: 0.0016 - val_mean_absolute_error: 0.0330
# Epoch 40/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0015 - mean_absolute_error: 0.0306 - val_loss: 0.0014 - val_mean_absolute_error: 0.0314
# Epoch 41/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0013 - mean_absolute_error: 0.0289 - val_loss: 0.0013 - val_mean_absolute_error: 0.0297
# Epoch 42/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0012 - mean_absolute_error: 0.0271 - val_loss: 0.0012 - val_mean_absolute_error: 0.0282
# Epoch 43/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0010 - mean_absolute_error: 0.0256 - val_loss: 0.0010 - val_mean_absolute_error: 0.0266
# Epoch 44/50
# 10/10 [==============================] - 0s 10ms/step - loss: 9.3177e-04 - mean_absolute_error: 0.0242 - val_loss: 9.2164e-04 - val_mean_absolute_error: 0.0252
# Epoch 45/50
# 10/10 [==============================] - 0s 10ms/step - loss: 8.2245e-04 - mean_absolute_error: 0.0227 - val_loss: 8.1862e-04 - val_mean_absolute_error: 0.0237
# Epoch 46/50
# 10/10 [==============================] - 0s 8ms/step - loss: 7.2626e-04 - mean_absolute_error: 0.0213 - val_loss: 7.2692e-04 - val_mean_absolute_error: 0.0224
# Epoch 47/50
# 10/10 [==============================] - 0s 8ms/step - loss: 6.4310e-04 - mean_absolute_error: 0.0199 - val_loss: 6.4567e-04 - val_mean_absolute_error: 0.0210
# Epoch 48/50
# 10/10 [==============================] - 0s 6ms/step - loss: 5.6965e-04 - mean_absolute_error: 0.0187 - val_loss: 5.6601e-04 - val_mean_absolute_error: 0.0197
# Epoch 49/50
# 10/10 [==============================] - 0s 5ms/step - loss: 5.0481e-04 - mean_absolute_error: 0.0175 - val_loss: 4.9923e-04 - val_mean_absolute_error: 0.0184
# Epoch 50/50
# 10/10 [==============================] - 0s 6ms/step - loss: 4.5335e-04 - mean_absolute_error: 0.0165 - val_loss: 4.3596e-04 - val_mean_absolute_error: 0.0173

# %%
tr_acc = history.history['mean_absolute_error']
tr_loss = history.history['loss']
val_acc = history.history['val_mean_absolute_error']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmin(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %%
ann_y_pred = ann.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step

# %%
r2 = r2_score(y_test, y_pred)
print('R2 score:', r2)
# Out:
# R2 score: 0.9999999816271219

# %%
ann.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 3.9981e-04 - mean_absolute_error: 0.0168
# [0.0003998080501332879, 0.016772767528891563]

# %%
ann.predict([[40, 70000.500, 9550,534000]])
# Out:
# 1/1 [==============================] - 0s 120ms/step
# array([[224098.05]], dtype=float32)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, label='Linear Regression')
plt.scatter(y_test, ann_y_pred, label='ANN')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='gray')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Predicted vs. Actual Values')
plt.legend()
plt.show()

# %%
threshold = 0.5  # Misalnya, gunakan nilai 0.5 sebagai threshold

# Convert predictions to class labels
y_pred_class = (y_pred > threshold).astype(int)

# Compute confusion matrix
conf_matrix = confusion_matrix(y_test > threshold, y_pred > threshold)

# Visualize confusion matrix using heatmap
plt.figure(figsize=(10, 6))
sns.set(font_scale=1.3)
sns.heatmap(conf_matrix, annot=True, fmt="d", linewidths=0.5, cbar=False, cmap='Blues')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
# Menentukan threshold
threshold = 0.5

# Mengubah prediksi menjadi label kelas
y_pred_class = (y_pred > threshold).astype(int)

# Menghitung classification report
classification_rep = classification_report(y_test > threshold, y_pred > threshold)

# Menampilkan classification report
print(classification_rep)
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00        53
#         True       1.00      1.00      1.00        47
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100
